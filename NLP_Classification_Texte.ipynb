# %% [markdown]
# <a href="https://colab.research.google.com/github/MANSUsra/Pre-processing/blob/main/NLP_Classification_Texte.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Je commence par le chargement du fichier concerné

# %%
import pandas as pd
from google.colab import files
import io
uploaded = files.upload()
# Out:
#      <input type="file" id="files-856c3b4d-5987-4e61-94a3-19c665438b28" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-856c3b4d-5987-4e61-94a3-19c665438b28">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('movie_review.csv')
df
# Out:
#        fold_id cv_tag  html_id  sent_id  \
# 0            0  cv000    29590        0
# 1            0  cv000    29590        1
# 2            0  cv000    29590        2
# 3            0  cv000    29590        3
# 4            0  cv000    29590        4
# ...        ...    ...      ...      ...
# 64715        9  cv999    14636       20
# 64716        9  cv999    14636       21
# 64717        9  cv999    14636       22
# 64718        9  cv999    14636       23
# 64719        9  cv999    14636       24
#
#                                                     text  tag
# 0      films adapted from comic books have had plenty...  pos
# 1      for starters , it was created by alan moore ( ...  pos
# 2      to say moore and campbell thoroughly researche...  pos
# 3      the book ( or " graphic novel , " if you will ...  pos
# 4      in other words , don't dismiss this film becau...  pos
# ...                                                  ...  ...
# ...

# %% [markdown]
# J'extrait les colonnes dont j'ai besoin

# %%
columns = df[['text', 'tag']]
columns
# Out:
#                                                     text  tag
# 0      films adapted from comic books have had plenty...  pos
# 1      for starters , it was created by alan moore ( ...  pos
# 2      to say moore and campbell thoroughly researche...  pos
# 3      the book ( or " graphic novel , " if you will ...  pos
# 4      in other words , don't dismiss this film becau...  pos
# ...                                                  ...  ...
# 64715  that lack of inspiration can be traced back to...  neg
# 64716  like too many of the skits on the current inca...  neg
# 64717  after watching one of the " roxbury " skits on...  neg
# 64718   bump unsuspecting women , and . . . that's all .  neg
# 64719  after watching _a_night_at_the_roxbury_ , you'...  neg
#
# [64720 rows x 2 columns]

# %% [markdown]
# Je commence le prétraitement

# %%
#Conversion du texte en minuscule
columns.loc[:, 'text'] = columns['text'].str.lower();
columns.loc[:, 'tag'] = columns['tag'].str.lower();
columns
# Out:
# <ipython-input-32-ac70e7743563>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns.loc[:, 'text'] = columns['text'].str.lower();
# <ipython-input-32-ac70e7743563>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns.loc[:, 'tag'] = columns['tag'].str.lower();
#                                                     text  tag
# 0      films adapted from comic books have had plenty...  pos
# 1      for starters , it was created by alan moore ( ...  pos
# ...

# %%
#Suppression des mots vides
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))
def remove_stopwords(text):
    words = text.split()
    filtered_text = [word for word in words if word not in stop_words]
    return ' '.join(filtered_text)
columns['text'] = columns['text'].apply(remove_stopwords)
columns['tag'] = columns['tag'].apply(remove_stopwords)
columns
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# <ipython-input-33-5859e24f8490>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns['text'] = columns['text'].apply(remove_stopwords)
# <ipython-input-33-5859e24f8490>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns['tag'] = columns['tag'].apply(remove_stopwords)
#                                                     text  tag
# ...

# %%
#Suppression de la ponctuation
import re
def remove_ponctuations(text):
  return re.sub(r'[^\w\s]', '', text)

columns['text'] = columns['text'].apply(remove_ponctuations)

columns
# Out:
# <ipython-input-34-11c1312d1cf6>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   columns['text'] = columns['text'].apply(remove_ponctuations)
#                                                     text  tag
# 0      films adapted comic books plenty success  whet...  pos
# 1      starters  created alan moore  eddie campbell  ...  pos
# 2      say moore campbell thoroughly researched subje...  pos
# 3      book   graphic novel    500 pages long include...  pos
# 4                            words  dismiss film source   pos
# ...                                                  ...  ...
# 64715   lack inspiration traced back insipid characters   neg
# 64716  like many skits current incarnation _saturday_...  neg
# ...

# %% [markdown]
# Entrainement du modèle Word2Vec

# %%
from gensim.models import Word2Vec

phrases = [text.split() for text in columns['text']]
taille_vecteur = 150
fenetre = 7
model_word2vec = Word2Vec(phrases, vector_size=taille_vecteur, window=fenetre)

# %% [markdown]
# Vectorisation des reviews de movies

# %%
import numpy as np
def calculer_review_embedding(review, model_word2vec, taille_vecteur):
    review_embedding = np.zeros(taille_vecteur)
    cp = 0
    for word in review.split():
        if word in model_word2vec.wv:
            review_embedding += model_word2vec.wv[word]
            cp +=1

    if cp != 0:

        review_embedding /= cp
    return review_embedding

# %% [markdown]
# Divisions des données

# %%
from sklearn.model_selection import train_test_split

taille_vecteur = 150
X_train, X_test, y_train, y_test = train_test_split(columns['text'], columns['tag'], test_size=0.2, random_state=42)
X_train_embeddings = np.array([calculer_review_embedding(review, model_word2vec, taille_vecteur) for review in X_train])
X_test_embeddings = np.array([calculer_review_embedding(review, model_word2vec, taille_vecteur) for review in X_test])

# %% [markdown]
# Construction du classificateur LogisticRegression

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train_embeddings, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Evaluation du modèle

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
pred = model.predict(X_test_embeddings)
accuracy = accuracy_score(y_test, pred)
print("Accuracy :", accuracy)

# Calculer la précision
precision = precision_score(y_test, pred, average='weighted')
print("Précision :", precision)

# Calculer le rappel
recall = recall_score(y_test, pred, average='weighted')
print("Recall :", recall)

# Calculer le score F1
f1 = f1_score(y_test, pred, average='weighted')
print("F1 score :", f1)
# Out:
# Accuracy : 0.5777966625463535
# Précision : 0.5793589610120058
# Recall : 0.5777966625463535
# F1 score : 0.5734191936588396
